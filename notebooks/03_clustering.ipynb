# %% [markdown]
# # 03 - Clustering
#
# This notebook applies KMeans and DBSCAN clustering algorithms.

# %%
# TODO: Load reduced data
# TODO: Apply elbow method for KMeans
# TODO: Apply KMeans clustering
# TODO: Apply DBSCAN clustering
# TODO: Evaluate using silhouette, Davies-Bouldin, Calinski-Harabasz
# TODO: Visualize clusters
